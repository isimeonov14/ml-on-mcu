# %% [markdown]
# # Machine Learning on MCU - Ex3.2
#
# This exercise will introduce you to Keras, one of the most popular frameworks used in Deep Learning.
#
# You will train a simple multi-layer perceptron to predict Human Activity from Smartphone Accelerometer and Gyroscope Data.
#
# We use a dataset of 3-axial accelerometer signals from an academic experiment on the UC Irvine Machine Learning Repository.
#
# The dataset is downloaded in the code snippet below and you can you can also find the description of the dataset [here](https://archive.ics.uci.edu/dataset/341/smartphone+based+recognition+of+human+activities+and+postural+transitions) .
#
# # Load the dataset

# %%
# If required, download the dataset
import requests
import os.path
import zipfile
from __future__ import division
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import random

random.seed(7)

if (not os.path.isdir('./HAPT Data Set')):
    open('./HAPT Data Set.zip', 'wb').write(requests.get(
        "https://archive.ics.uci.edu/ml/machine-learning-databases/00341/HAPT%20Data%20Set.zip", 
        allow_redirects=True).content)
    zipfile.ZipFile('./HAPT Data Set.zip', 'r').extractall('./HAPT Data Set')

# %% [markdown]
# Load the accelerometer and gyroscope data.
# We read the feature names from features.txt and the activity labels from activity_labels.txt

# %%
with open('./HAPT Data Set/features.txt') as f:
    features = f.read().split()

print('There are {} features.'.format(len(features)))
    
with open('./HAPT Data Set/activity_labels.txt') as f:
    activity_labels = f.readlines()

activity_df = [x.split() for x in activity_labels]
print('There are {} activities.'.format(len(activity_df)))
pd.DataFrame(activity_df, columns = ['Activity_id', 'Activity_label'])
# Out:
# There are 561 features.
# There are 12 activities.
#    Activity_id      Activity_label
# 0            1             WALKING
# 1            2    WALKING_UPSTAIRS
# 2            3  WALKING_DOWNSTAIRS
# 3            4             SITTING
# 4            5            STANDING
# 5            6              LAYING
# 6            7        STAND_TO_SIT
# 7            8        SIT_TO_STAND
# 8            9          SIT_TO_LIE
# 9           10          LIE_TO_SIT
# 10          11        STAND_TO_LIE
# 11          12        LIE_TO_STAND

# %% [markdown]
# The data are pre-split into training and test sets. Let's load the features x and the labels y, and have a look at a few features.

# %%
X_train = pd.read_table('./HAPT Data Set/Train/X_train.txt',
             header = None, sep = " ", names = list(dict.fromkeys(features)))
X_train.iloc[:10, :10].head()
# Out:
#                                                                                                                                                                                                                                                                                    tBodyAcc-Mean-1  \
# 0.043580 -0.005970 -0.035054 -0.995381 -0.988366 -0.937382 -0.995007 -0.988816 -0.953325 -0.794796 -0.744893 -0.648447 0.841796 0.708440 0.651716 -0.975752 -0.999950 -0.999888 -0.998014 -0.993999 -0.991980 -0.970970 -0.547095 -0.700974 -0.622697 0.921884 -0.719483 0.342168        -0.161318
# 0.039480 -0.002131 -0.029067 -0.998348 -0.982945 -0.971273 -0.998702 -0.983315 -0.974000 -0.802537 -0.736338 -0.712415 0.838758 0.708440 0.659340 -0.987427 -0.999993 -0.999826 -0.999411 -0.998918 -0.985482 -0.973481 -0.781973 -0.534604 -0.593165 0.607435 -0.266783 0.275882         0.200417
# 0.039978 -0.005153 -0.022651 -0.995482 -0.977314 -0.984760 -0.996415 -0.975835 -0.985973 -0.798477 -0.736338 -0.712415 0.834002 0.705008 0.674551 -0.988528 -0.999972 -0.999719 -0.999803 -0.996898 -0.976781 -0.986754 -0.688176 -0.520514 -0.593165 0.272262 -0.056424 0.322283        -0.273292
# 0.039785 -0.011809 -0.028916 -0.996194 -0.988569 -0.993256 -0.996994 -0.988526 -0.993135 -0.798477 -0.752778 -0.722186 0.834002 0.705008 0.673208 -0.990389 -0.999978 -0.999783 -0.999815 -0.996949 -0.989437 -0.992440 -0.715103 -0.860988 -0.916429 0.062816  0.082940 0.200566        -0.378262
# 0.038758 -0.002289 -0.023863 -0.998241 -0.986774 -0.993115 -0.998216 -0.986479 -0.993825 -0.801982 -0.746505 -0.717858 0.838581 0.705854 0.673208 -0.995057 -0.999992 -0.999882 -0.999908 -0.997772 -0.987726 -0.995109 -0.836774 -0.589200 -0.773771 0.312105 -0.095254 0.194399        -0.007998
#
#                                                                                                                                                                                                                                                                                    tBodyAcc-Mean-2  \
# 0.043580 -0.005970 -0.035054 -0.995381 -0.988366 -0.937382 -0.995007 -0.988816 -0.953325 -0.794796 -0.744893 -0.648447 0.841796 0.708440 0.651716 -0.975752 -0.999950 -0.999888 -0.998014 -0.993999 -0.991980 -0.970970 -0.547095 -0.700974 -0.622697 0.921884 -0.719483 0.342168         0.266049
# 0.039480 -0.002131 -0.029067 -0.998348 -0.982945 -0.971273 -0.998702 -0.983315 -0.974000 -0.802537 -0.736338 -0.712415 0.838758 0.708440 0.659340 -0.987427 -0.999993 -0.999826 -0.999411 -0.998918 -0.985482 -0.973481 -0.781973 -0.534604 -0.593165 0.607435 -0.266783 0.275882         0.131266
# 0.039978 -0.005153 -0.022651 -0.995482 -0.977314 -0.984760 -0.996415 -0.975835 -0.985973 -0.798477 -0.736338 -0.712415 0.834002 0.705008 0.674551 -0.988528 -0.999972 -0.999719 -0.999803 -0.996898 -0.976781 -0.986754 -0.688176 -0.520514 -0.593165 0.272262 -0.056424 0.322283         0.037180
# 0.039785 -0.011809 -0.028916 -0.996194 -0.988569 -0.993256 -0.996994 -0.988526 -0.993135 -0.798477 -0.752778 -0.722186 0.834002 0.705008 0.673208 -0.990389 -0.999978 -0.999783 -0.999815 -0.996949 -0.989437 -0.992440 -0.715103 -0.860988 -0.916429 0.062816  0.082940 0.200566         0.090063
# 0.038758 -0.002289 -0.023863 -0.998241 -0.986774 -0.993115 -0.998216 -0.986479 -0.993825 -0.801982 -0.746505 -0.717858 0.838581 0.705854 0.673208 -0.995057 -0.999992 -0.999882 -0.999908 -0.997772 -0.987726 -0.995109 -0.836774 -0.589200 -0.773771 0.312105 -0.095254 0.194399         0.266740
#
#                                                                                                                                                                                                                                                                                    tBodyAcc-Mean-3  \
# 0.043580 -0.005970 -0.035054 -0.995381 -0.988366 -0.937382 -0.995007 -0.988816 -0.953325 -0.794796 -0.744893 -0.648447 0.841796 0.708440 0.651716 -0.975752 -0.999950 -0.999888 -0.998014 -0.993999 -0.991980 -0.970970 -0.547095 -0.700974 -0.622697 0.921884 -0.719483 0.342168        -0.274351
# 0.039480 -0.002131 -0.029067 -0.998348 -0.982945 -0.971273 -0.998702 -0.983315 -0.974000 -0.802537 -0.736338 -0.712415 0.838758 0.708440 0.659340 -0.987427 -0.999993 -0.999826 -0.999411 -0.998918 -0.985482 -0.973481 -0.781973 -0.534604 -0.593165 0.607435 -0.266783 0.275882        -0.149017
# 0.039978 -0.005153 -0.022651 -0.995482 -0.977314 -0.984760 -0.996415 -0.975835 -0.985973 -0.798477 -0.736338 -0.712415 0.834002 0.705008 0.674551 -0.988528 -0.999972 -0.999719 -0.999803 -0.996898 -0.976781 -0.986754 -0.688176 -0.520514 -0.593165 0.272262 -0.056424 0.322283        -0.133612
# 0.039785 -0.011809 -0.028916 -0.996194 -0.988569 -0.993256 -0.996994 -0.988526 -0.993135 -0.798477 -0.752778 -0.722186 0.834002 0.705008 0.673208 -0.990389 -0.999978 -0.999783 -0.999815 -0.996949 -0.989437 -0.992440 -0.715103 -0.860988 -0.916429 0.062816  0.082940 0.200566        -0.209264
# 0.038758 -0.002289 -0.023863 -0.998241 -0.986774 -0.993115 -0.998216 -0.986479 -0.993825 -0.801982 -0.746505 -0.717858 0.838581 0.705854 0.673208 -0.995057 -0.999992 -0.999882 -0.999908 -0.997772 -0.987726 -0.995109 -0.836774 -0.589200 -0.773771 0.312105 -0.095254 0.194399        -0.318965
#
#                                                                                                                                                                                                                                                                                    tBodyAcc-STD-1  \
# 0.043580 -0.005970 -0.035054 -0.995381 -0.988366 -0.937382 -0.995007 -0.988816 -0.953325 -0.794796 -0.744893 -0.648447 0.841796 0.708440 0.651716 -0.975752 -0.999950 -0.999888 -0.998014 -0.993999 -0.991980 -0.970970 -0.547095 -0.700974 -0.622697 0.921884 -0.719483 0.342168        0.267205
# 0.039480 -0.002131 -0.029067 -0.998348 -0.982945 -0.971273 -0.998702 -0.983315 -0.974000 -0.802537 -0.736338 -0.712415 0.838758 0.708440 0.659340 -0.987427 -0.999993 -0.999826 -0.999411 -0.998918 -0.985482 -0.973481 -0.781973 -0.534604 -0.593165 0.607435 -0.266783 0.275882        0.292436
# 0.039978 -0.005153 -0.022651 -0.995482 -0.977314 -0.984760 -0.996415 -0.975835 -0.985973 -0.798477 -0.736338 -0.712415 0.834002 0.705008 0.674551 -0.988528 -0.999972 -0.999719 -0.999803 -0.996898 -0.976781 -0.986754 -0.688176 -0.520514 -0.593165 0.272262 -0.056424 0.322283        0.332487
# 0.039785 -0.011809 -0.028916 -0.996194 -0.988569 -0.993256 -0.996994 -0.988526 -0.993135 -0.798477 -0.752778 -0.722186 0.834002 0.705008 0.673208 -0.990389 -0.999978 -0.999783 -0.999815 -0.996949 -0.989437 -0.992440 -0.715103 -0.860988 -0.916429 0.062816  0.082940 0.200566        0.316530
# 0.038758 -0.002289 -0.023863 -0.998241 -0.986774 -0.993115 -0.998216 -0.986479 -0.993825 -0.801982 -0.746505 -0.717858 0.838581 0.705854 0.673208 -0.995057 -0.999992 -0.999882 -0.999908 -0.997772 -0.987726 -0.995109 -0.836774 -0.589200 -0.773771 0.312105 -0.095254 0.194399        0.409731
#
#                                                                                                                                                                                                                                                                                    tBodyAcc-STD-2  \
# 0.043580 -0.005970 -0.035054 -0.995381 -0.988366 -0.937382 -0.995007 -0.988816 -0.953325 -0.794796 -0.744893 -0.648447 0.841796 0.708440 0.651716 -0.975752 -0.999950 -0.999888 -0.998014 -0.993999 -0.991980 -0.970970 -0.547095 -0.700974 -0.622697 0.921884 -0.719483 0.342168       -0.020958
# 0.039480 -0.002131 -0.029067 -0.998348 -0.982945 -0.971273 -0.998702 -0.983315 -0.974000 -0.802537 -0.736338 -0.712415 0.838758 0.708440 0.659340 -0.987427 -0.999993 -0.999826 -0.999411 -0.998918 -0.985482 -0.973481 -0.781973 -0.534604 -0.593165 0.607435 -0.266783 0.275882       -0.192986
# 0.039978 -0.005153 -0.022651 -0.995482 -0.977314 -0.984760 -0.996415 -0.975835 -0.985973 -0.798477 -0.736338 -0.712415 0.834002 0.705008 0.674551 -0.988528 -0.999972 -0.999719 -0.999803 -0.996898 -0.976781 -0.986754 -0.688176 -0.520514 -0.593165 0.272262 -0.056424 0.322283       -0.240491
# 0.039785 -0.011809 -0.028916 -0.996194 -0.988569 -0.993256 -0.996994 -0.988526 -0.993135 -0.798477 -0.752778 -0.722186 0.834002 0.705008 0.673208 -0.990389 -0.999978 -0.999783 -0.999815 -0.996949 -0.989437 -0.992440 -0.715103 -0.860988 -0.916429 0.062816  0.082940 0.200566       -0.090862
# 0.038758 -0.002289 -0.023863 -0.998241 -0.986774 -0.993115 -0.998216 -0.986479 -0.993825 -0.801982 -0.746505 -0.717858 0.838581 0.705854 0.673208 -0.995057 -0.999992 -0.999882 -0.999908 -0.997772 -0.987726 -0.995109 -0.836774 -0.589200 -0.773771 0.312105 -0.095254 0.194399       -0.224589
#
#                                                                                                                                                                                                                                                                                    tBodyAcc-STD-3  \
# 0.043580 -0.005970 -0.035054 -0.995381 -0.988366 -0.937382 -0.995007 -0.988816 -0.953325 -0.794796 -0.744893 -0.648447 0.841796 0.708440 0.651716 -0.975752 -0.999950 -0.999888 -0.998014 -0.993999 -0.991980 -0.970970 -0.547095 -0.700974 -0.622697 0.921884 -0.719483 0.342168        0.382610
# 0.039480 -0.002131 -0.029067 -0.998348 -0.982945 -0.971273 -0.998702 -0.983315 -0.974000 -0.802537 -0.736338 -0.712415 0.838758 0.708440 0.659340 -0.987427 -0.999993 -0.999826 -0.999411 -0.998918 -0.985482 -0.973481 -0.781973 -0.534604 -0.593165 0.607435 -0.266783 0.275882        0.217496
# 0.039978 -0.005153 -0.022651 -0.995482 -0.977314 -0.984760 -0.996415 -0.975835 -0.985973 -0.798477 -0.736338 -0.712415 0.834002 0.705008 0.674551 -0.988528 -0.999972 -0.999719 -0.999803 -0.996898 -0.976781 -0.986754 -0.688176 -0.520514 -0.593165 0.272262 -0.056424 0.322283        0.348733
# 0.039785 -0.011809 -0.028916 -0.996194 -0.988569 -0.993256 -0.996994 -0.988526 -0.993135 -0.798477 -0.752778 -0.722186 0.834002 0.705008 0.673208 -0.990389 -0.999978 -0.999783 -0.999815 -0.996949 -0.989437 -0.992440 -0.715103 -0.860988 -0.916429 0.062816  0.082940 0.200566        0.396383
# 0.038758 -0.002289 -0.023863 -0.998241 -0.986774 -0.993115 -0.998216 -0.986479 -0.993825 -0.801982 -0.746505 -0.717858 0.838581 0.705854 0.673208 -0.995057 -0.999992 -0.999882 -0.999908 -0.997772 -0.987726 -0.995109 -0.836774 -0.589200 -0.773771 0.312105 -0.095254 0.194399        0.520354
#
#                                                                                                                                                                                                                                                                                    tBodyAcc-Mad-1  \
# 0.043580 -0.005970 -0.035054 -0.995381 -0.988366 -0.937382 -0.995007 -0.988816 -0.953325 -0.794796 -0.744893 -0.648447 0.841796 0.708440 0.651716 -0.975752 -0.999950 -0.999888 -0.998014 -0.993999 -0.991980 -0.970970 -0.547095 -0.700974 -0.622697 0.921884 -0.719483 0.342168       -0.501748
# 0.039480 -0.002131 -0.029067 -0.998348 -0.982945 -0.971273 -0.998702 -0.983315 -0.974000 -0.802537 -0.736338 -0.712415 0.838758 0.708440 0.659340 -0.987427 -0.999993 -0.999826 -0.999411 -0.998918 -0.985482 -0.973481 -0.781973 -0.534604 -0.593165 0.607435 -0.266783 0.275882       -0.089175
# 0.039978 -0.005153 -0.022651 -0.995482 -0.977314 -0.984760 -0.996415 -0.975835 -0.985973 -0.798477 -0.736338 -0.712415 0.834002 0.705008 0.674551 -0.988528 -0.999972 -0.999719 -0.999803 -0.996898 -0.976781 -0.986754 -0.688176 -0.520514 -0.593165 0.272262 -0.056424 0.322283       -0.195409
# 0.039785 -0.011809 -0.028916 -0.996194 -0.988569 -0.993256 -0.996994 -0.988526 -0.993135 -0.798477 -0.752778 -0.722186 0.834002 0.705008 0.673208 -0.990389 -0.999978 -0.999783 -0.999815 -0.996949 -0.989437 -0.992440 -0.715103 -0.860988 -0.916429 0.062816  0.082940 0.200566       -0.353643
# 0.038758 -0.002289 -0.023863 -0.998241 -0.986774 -0.993115 -0.998216 -0.986479 -0.993825 -0.801982 -0.746505 -0.717858 0.838581 0.705854 0.673208 -0.995057 -0.999992 -0.999882 -0.999908 -0.997772 -0.987726 -0.995109 -0.836774 -0.589200 -0.773771 0.312105 -0.095254 0.194399       -0.319167
#
#                                                                                                                                                                                                                                                                                    tBodyAcc-Mad-2  \
# 0.043580 -0.005970 -0.035054 -0.995381 -0.988366 -0.937382 -0.995007 -0.988816 -0.953325 -0.794796 -0.744893 -0.648447 0.841796 0.708440 0.651716 -0.975752 -0.999950 -0.999888 -0.998014 -0.993999 -0.991980 -0.970970 -0.547095 -0.700974 -0.622697 0.921884 -0.719483 0.342168        0.512463
# 0.039480 -0.002131 -0.029067 -0.998348 -0.982945 -0.971273 -0.998702 -0.983315 -0.974000 -0.802537 -0.736338 -0.712415 0.838758 0.708440 0.659340 -0.987427 -0.999993 -0.999826 -0.999411 -0.998918 -0.985482 -0.973481 -0.781973 -0.534604 -0.593165 0.607435 -0.266783 0.275882        0.059909
# 0.039978 -0.005153 -0.022651 -0.995482 -0.977314 -0.984760 -0.996415 -0.975835 -0.985973 -0.798477 -0.736338 -0.712415 0.834002 0.705008 0.674551 -0.988528 -0.999972 -0.999719 -0.999803 -0.996898 -0.976781 -0.986754 -0.688176 -0.520514 -0.593165 0.272262 -0.056424 0.322283        0.229436
# 0.039785 -0.011809 -0.028916 -0.996194 -0.988569 -0.993256 -0.996994 -0.988526 -0.993135 -0.798477 -0.752778 -0.722186 0.834002 0.705008 0.673208 -0.990389 -0.999978 -0.999783 -0.999815 -0.996949 -0.989437 -0.992440 -0.715103 -0.860988 -0.916429 0.062816  0.082940 0.200566        0.503754
# 0.038758 -0.002289 -0.023863 -0.998241 -0.986774 -0.993115 -0.998216 -0.986479 -0.993825 -0.801982 -0.746505 -0.717858 0.838581 0.705854 0.673208 -0.995057 -0.999992 -0.999882 -0.999908 -0.997772 -0.987726 -0.995109 -0.836774 -0.589200 -0.773771 0.312105 -0.095254 0.194399        0.234376
#
#                                                                                                                                                                                                                                                                                    tBodyAcc-Mad-3  \
# 0.043580 -0.005970 -0.035054 -0.995381 -0.988366 -0.937382 -0.995007 -0.988816 -0.953325 -0.794796 -0.744893 -0.648447 0.841796 0.708440 0.651716 -0.975752 -0.999950 -0.999888 -0.998014 -0.993999 -0.991980 -0.970970 -0.547095 -0.700974 -0.622697 0.921884 -0.719483 0.342168       -0.206337
# 0.039480 -0.002131 -0.029067 -0.998348 -0.982945 -0.971273 -0.998702 -0.983315 -0.974000 -0.802537 -0.736338 -0.712415 0.838758 0.708440 0.659340 -0.987427 -0.999993 -0.999826 -0.999411 -0.998918 -0.985482 -0.973481 -0.781973 -0.534604 -0.593165 0.607435 -0.266783 0.275882       -0.236609
# 0.039978 -0.005153 -0.022651 -0.995482 -0.977314 -0.984760 -0.996415 -0.975835 -0.985973 -0.798477 -0.736338 -0.712415 0.834002 0.705008 0.674551 -0.988528 -0.999972 -0.999719 -0.999803 -0.996898 -0.976781 -0.986754 -0.688176 -0.520514 -0.593165 0.272262 -0.056424 0.322283       -0.316816
# 0.039785 -0.011809 -0.028916 -0.996194 -0.988569 -0.993256 -0.996994 -0.988526 -0.993135 -0.798477 -0.752778 -0.722186 0.834002 0.705008 0.673208 -0.990389 -0.999978 -0.999783 -0.999815 -0.996949 -0.989437 -0.992440 -0.715103 -0.860988 -0.916429 0.062816  0.082940 0.200566       -0.490389
# 0.038758 -0.002289 -0.023863 -0.998241 -0.986774 -0.993115 -0.998216 -0.986479 -0.993825 -0.801982 -0.746505 -0.717858 0.838581 0.705854 0.673208 -0.995057 -0.999992 -0.999882 -0.999908 -0.997772 -0.987726 -0.995109 -0.836774 -0.589200 -0.773771 0.312105 -0.095254 0.194399       -0.102650
#
#                                                                                                                                                                                                                                                                                    tBodyAcc-Max-1
# 0.043580 -0.005970 -0.035054 -0.995381 -0.988366 -0.937382 -0.995007 -0.988816 -0.953325 -0.794796 -0.744893 -0.648447 0.841796 0.708440 0.651716 -0.975752 -0.999950 -0.999888 -0.998014 -0.993999 -0.991980 -0.970970 -0.547095 -0.700974 -0.622697 0.921884 -0.719483 0.342168        0.376778
# 0.039480 -0.002131 -0.029067 -0.998348 -0.982945 -0.971273 -0.998702 -0.983315 -0.974000 -0.802537 -0.736338 -0.712415 0.838758 0.708440 0.659340 -0.987427 -0.999993 -0.999826 -0.999411 -0.998918 -0.985482 -0.973481 -0.781973 -0.534604 -0.593165 0.607435 -0.266783 0.275882       -0.012696
# 0.039978 -0.005153 -0.022651 -0.995482 -0.977314 -0.984760 -0.996415 -0.975835 -0.985973 -0.798477 -0.736338 -0.712415 0.834002 0.705008 0.674551 -0.988528 -0.999972 -0.999719 -0.999803 -0.996898 -0.976781 -0.986754 -0.688176 -0.520514 -0.593165 0.272262 -0.056424 0.322283       -0.123889
# 0.039785 -0.011809 -0.028916 -0.996194 -0.988569 -0.993256 -0.996994 -0.988526 -0.993135 -0.798477 -0.752778 -0.722186 0.834002 0.705008 0.673208 -0.990389 -0.999978 -0.999783 -0.999815 -0.996949 -0.989437 -0.992440 -0.715103 -0.860988 -0.916429 0.062816  0.082940 0.200566       -0.304759
# 0.038758 -0.002289 -0.023863 -0.998241 -0.986774 -0.993115 -0.998216 -0.986479 -0.993825 -0.801982 -0.746505 -0.717858 0.838581 0.705854 0.673208 -0.995057 -0.999992 -0.999882 -0.999908 -0.997772 -0.987726 -0.995109 -0.836774 -0.589200 -0.773771 0.312105 -0.095254 0.194399       -0.154974

# %%
y_train = pd.read_table('./HAPT Data Set/Train/y_train.txt',
             header = None, sep = " ", names = ['Activity_id'])
y_train.head()
# Out:
#    Activity_id
# 0            5
# 1            5
# 2            5
# 3            5
# 4            5

# %%
X_test = pd.read_table('./HAPT Data Set/Test/X_test.txt',
             header = None, sep = " ", names = list(dict.fromkeys(features)))
y_test = pd.read_table('./HAPT Data Set/Test/y_test.txt',
             header = None, sep = " ", names = ['Activity_id'])

# %% [markdown]
# ## Predict Human Activity

# %%
# Import the necessary packages
from sklearn.model_selection import train_test_split

# Note: use Tensor Flow backend for Keras as suggested on keras.io:
# "At this time, we recommend that Keras users who use multi-backend Keras with the TensorFlow backend switch to tf.keras in TensorFlow 2.0. tf.keras is better maintained and has better integration with TensorFlow features (eager execution, distribution support and other)."
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import layers, models, regularizers

# %%
# Load the accelerometer and gyroscope data. Apply features
X_train = X_train.to_numpy()
y_train = y_train.to_numpy()
X_test = X_test.to_numpy()
y_test = y_test.to_numpy()

# %%
X_train.shape
# Out:
# (7767, 533)

# %%
# Split the dataset into training, validation, and testing sets. (You can take example from ex 1 and 2.)
X_train_split, X_val_split, y_train_split, y_val_split = train_test_split(X_train, y_train, test_size = 0.2, random_state = 0)

print(f"X_train_split shape: {X_train_split.shape}")
print(f"y_train_split shape: {y_train_split.shape}")
print(f"X_val_split shape: {X_val_split.shape}")
print(f"y_val_split shape: {y_val_split.shape}")
# Out:
# X_train_split shape: (6213, 533)
# y_train_split shape: (6213, 1)
# X_val_split shape: (1554, 533)
# y_val_split shape: (1554, 1)

# %%
# # DO NOT RERUN ONE-HOT ENCODING
from keras.utils import to_categorical

outputShape = (12)

y_train_split -= 1
y_val_split -= 1

y_train_split = to_categorical(y_train_split, num_classes=outputShape)
y_val_split = to_categorical(y_val_split, num_classes=outputShape)

print(f"y_val_split shape: {y_val_split.shape}")
print(f"X_val_split shape: {X_val_split.shape}")
# Out:
# y_val_split shape: (1554, 12)
# X_val_split shape: (1554, 533)

# %%
from tensorflow.keras.layers import Dropout
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import BatchNormalization

# Define batchsize and number of epochs
batchSize = 400
epochs = 50

# Shceduler 
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=0.00001)


# Optimizer
initial_learning_rate = 0.003  
optimizer = Adam(learning_rate=initial_learning_rate)

# Declare the sequential model and design your multi-layer perception

model = models.Sequential()
model.add(layers.Flatten(input_shape=(X_train_split.shape[1],)))  
model.add(layers.Dense(128, activation='relu',kernel_regularizer=regularizers.l2(0.001)))
#model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(layers.Dense(64, activation='relu',kernel_regularizer=regularizers.l2(0.001)))
#model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(layers.Dense(32, activation='relu',kernel_regularizer=regularizers.l2(0.001)))
#model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(layers.Dense(16, activation='relu',kernel_regularizer=regularizers.l2(0.001)))
model.add(layers.Dense(outputShape, activation='softmax'))

# Compile your model
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# Train your model
history = model.fit(X_train_split, y_train_split, 
                    batch_size=batchSize, 
                    epochs=epochs, 
                    validation_data=(X_val_split, y_val_split),
                    callbacks=[reduce_lr])
# Out:
# Epoch 1/50
# 16/16 [==============================] - 1s 19ms/step - loss: 2.5011 - accuracy: 0.2141 - val_loss: 1.8440 - val_accuracy: 0.3314 - lr: 0.0030
# Epoch 2/50
# 16/16 [==============================] - 0s 7ms/step - loss: 1.8499 - accuracy: 0.3432 - val_loss: 1.4310 - val_accuracy: 0.5296 - lr: 0.0030
# Epoch 3/50
# 16/16 [==============================] - 0s 7ms/step - loss: 1.5033 - accuracy: 0.4246 - val_loss: 1.1745 - val_accuracy: 0.6062 - lr: 0.0030
# Epoch 4/50
# 16/16 [==============================] - 0s 7ms/step - loss: 1.2535 - accuracy: 0.5434 - val_loss: 0.9896 - val_accuracy: 0.6905 - lr: 0.0030
# Epoch 5/50
# 16/16 [==============================] - 0s 7ms/step - loss: 1.0799 - accuracy: 0.6193 - val_loss: 0.8064 - val_accuracy: 0.7677 - lr: 0.0030
# Epoch 6/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.9289 - accuracy: 0.6906 - val_loss: 0.6726 - val_accuracy: 0.7986 - lr: 0.0030
# Epoch 7/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.8266 - accuracy: 0.7132 - val_loss: 0.6210 - val_accuracy: 0.7921 - lr: 0.0030
# Epoch 8/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.7649 - accuracy: 0.7351 - val_loss: 0.6021 - val_accuracy: 0.7851 - lr: 0.0030
# Epoch 9/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.7171 - accuracy: 0.7603 - val_loss: 0.5805 - val_accuracy: 0.7896 - lr: 0.0030
# Epoch 10/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6726 - accuracy: 0.7689 - val_loss: 0.5679 - val_accuracy: 0.7954 - lr: 0.0030
# Epoch 11/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6710 - accuracy: 0.7665 - val_loss: 0.5619 - val_accuracy: 0.7967 - lr: 0.0030
# Epoch 12/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.
50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3983 - accuracy: 0.9071 - val_loss: 0.3113 - val_accuracy: 0.9402 - lr: 0.0015
# Epoch 37/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3896 - accuracy: 0.9150 - val_loss: 0.3049 - val_accuracy: 0.9402 - lr: 0.0015
# Epoch 38/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4181 - accuracy: 0.8991 - val_loss: 0.3079 - val_accuracy: 0.9395 - lr: 0.0015
# Epoch 39/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4243 - accuracy: 0.8970 - val_loss: 0.2986 - val_accuracy: 0.9395 - lr: 0.0015
# Epoch 40/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.4028 - accuracy: 0.9073 - val_loss: 0.2932 - val_accuracy: 0.9434 - lr: 0.0015
# Epoch 41/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3817 - accuracy: 0.9160 - val_loss: 0.3083 - val_accuracy: 0.9382 - lr: 0.0015
# Epoch 42/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4054 - accuracy: 0.9070 - val_loss: 0.3081 - val_accuracy: 0.9356 - lr: 0.0015
# Epoch 43/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4015 - accuracy: 0.9084 - val_loss: 0.2923 - val_accuracy: 0.9434 - lr: 0.0015
# Epoch 44/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3881 - accuracy: 0.9118 - val_loss: 0.2885 - val_accuracy: 0.9421 - lr: 0.0015
# Epoch 45/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3740 - accuracy: 0.9152 - val_loss: 0.2809 - val_accuracy: 0.9447 - lr: 0.0015
# Epoch 46/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3742 - accuracy: 0.9176 - val_loss: 0.2874 - val_accuracy: 0.9459 - lr: 0.0015
# Epoch 47/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3811 - accuracy: 0.9139 - val_loss: 0.2770 - val_accuracy: 0.9459 - lr: 0.0015
# Epoch 48/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3782 - accuracy: 0.9144 - val_loss: 0.2792 - val_accuracy: 0.9447 - lr: 0.0015
# Epoch 49/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3661 - accuracy: 0.9198 - val_loss: 0.2806 - val_accuracy: 0.9414 - lr: 0.0015
# Epoch 50/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3600 - accuracy: 0.9187 - val_loss: 0.2767 - val_accuracy: 0.9434 - lr: 0.0015

# %%
# Plot the Training

loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# Number of epochs
epochs_range = range(1, epochs + 1)

# Plot Loss
plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs_range, accuracy, label='Training Accuracy')
plt.plot(epochs_range, val_accuracy, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
# You can use model.summary() to get an overview of your model
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_5 (Flatten)         (None, 533)               0
#
#  dense_25 (Dense)            (None, 128)               68352
#
#  dropout_15 (Dropout)        (None, 128)               0
#
#  dense_26 (Dense)            (None, 64)                8256
#
#  dropout_16 (Dropout)        (None, 64)                0
#
#  dense_27 (Dense)            (None, 32)                2080
#
#  dropout_17 (Dropout)        (None, 32)                0
#
#  dense_28 (Dense)            (None, 16)                528
#
#  dense_29 (Dense)            (None, 12)                204
#
# =================================================================
# Total params: 79,420
# Trainable params: 79,420
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Evaluate your model
val_loss, val_accuracy = model.evaluate(X_val_split, y_val_split)
print(f'Validation accuracy: {val_accuracy:.4f}')
# Out:
# 49/49 [==============================] - 0s 1ms/step - loss: 0.2767 - accuracy: 0.9434
# Validation accuracy: 0.9434

# %%
# Save your model once you are satisfied with it
model.save('Predict_Human_Activity_model.h5')

# %%
# DO NOT RERUN ONE-HOT ENCODING
y_test -= 1 
y_test = to_categorical(y_test, num_classes=12)

# %%
# Load your saved model and test on the test data.
from tensorflow.keras.models import load_model

loaded_model = load_model('Predict_Human_Activity_model.h5')

# Evaluate on test data
test_loss, test_accuracy = loaded_model.evaluate(X_test, y_test)
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3551 - accuracy: 0.9304
# Test Accuracy: 0.9304
